# %% [markdown]
# ## Data Class

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_image(tensor):
    # Convert the PyTorch tensor to a numpy array
    tensor = tensor.numpy().squeeze()

    # Get the number of layers
    num_layers = tensor.shape[0]
    print(tensor.shape)
    # Plot each layer as a subplot
    fig, axs = plt.subplots(1, num_layers, figsize=(15,5))
    for i in range(num_layers):
        axs[i].imshow(tensor[i], cmap='gray')
        axs[i].axis('off')
    plt.show()

# %%
plot_image(next(iter(data_loader))[0])
# Out:
# (5, 512, 512)
